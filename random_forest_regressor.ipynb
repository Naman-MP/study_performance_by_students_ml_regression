# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/Users/namanmp/ml_projects/Student_Performance.csv')
X = dataset.iloc[:, :4].values
y = dataset.iloc[:, -1].values.reshape(-1,1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X
# Out:
# array([[0.0, 1.0, 7, 99, 9],
#        [1.0, 0.0, 4, 82, 4],
#        [0.0, 1.0, 8, 51, 7],
#        ...,
#        [0.0, 1.0, 6, 83, 8],
#        [0.0, 1.0, 9, 97, 7],
#        [1.0, 0.0, 7, 74, 8]], shape=(10000, 5), dtype=object)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X)
X = imputer.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
regressor = RandomForestRegressor(n_estimators = 99999, random_state = 0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)

r2_score(y_test, y_pred)
# Out:
# /Users/namanmp/anaconda3/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.9835627149872799
